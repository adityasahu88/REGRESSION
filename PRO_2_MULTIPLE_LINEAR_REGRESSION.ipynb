# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
import seaborn as sns

# %%
df=pd.read_csv("Ecommerce Customers_Kaggle.csv")

# %%
df
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %% [markdown]
# # Top 5 records

# %%
df.head(5)
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %% [markdown]
# # Bottom 5 Records

# %%
df.tail(5)
# Out:
#                             Email  \
# 495  lewisjessica@craig-evans.com
# 496           katrina56@gmail.com
# 497            dale88@hotmail.com
# 498           cwilson@hotmail.com
# 499     hannahwilson@davidson.com
#
#                                                Address         Avatar  \
# 495  4483 Jones Motorway Suite 872\nLake Jamiefurt,...            Tan
# 496  172 Owen Divide Suite 497\nWest Richard, CA 19320  PaleVioletRed
# 497  0787 Andrews Ranch Apt. 633\nSouth Chadburgh, ...       Cornsilk
# 498  680 Jennifer Lodge Apt. 808\nBrendachester, TX...           Teal
# 499  49791 Rachel Heights Apt. 898\nEast Drewboroug...    DarkMagenta
#
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# ...

# %%
# total No of Record
df.shape
# Out:
# (500, 8)

# %%
# Column wise Information like datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
# Basis statistics Information
df.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
# check any null values
df.isnull().sum()
# Out:
# Email                   0
# Address                 0
# Avatar                  0
# Avg. Session Length     0
# Time on App             0
# Time on Website         0
# Length of Membership    0
# Yearly Amount Spent     0
# dtype: int64

# %%
# check any duplicates values
df.duplicated().sum()
# Out:
# 0

# %%
# Top 10 customers based on  Time spend on App
df.sort_values(by="Time on App",ascending=False).head(10)
# Out:
#                                 Email  \
# 65                     kyang@diaz.org
# 18            alejandro75@hotmail.com
# 260              george02@hotmail.com
# 286            bhill@pierce-kane.info
# 340           vancealicia@hotmail.com
# 247                 vmartin@yahoo.com
# 435  sanchezamber@scott-patterson.com
# 464             susanibarra@yahoo.com
# 258       russellbaldwin@ferrell.info
# 428               kevin45@mathews.net
#
#                                                Address      Avatar  \
# 65    223 Love Trail Suite 831\nPort Jeffrey, IN 46849   OliveDrab
# 18   64475 Andre Club Apt. 795\nPort Dannytown, PW ...        Cyan
# 260      3286 Lynch Field\nHenrychester, RI 41833-7902  LightCoral
# 286  3324 Branch Squares Suite 221\nRiddleton, OK 3...   RoyalBlue
# 340  06307 Scott Spurs Suite 161\nJessicaburgh, NH ...   RoyalBlue
# 247   30242 Rubio Forest\nPort Kyleland, VA 18339-5779   Turquoise
# 435     257 Hunt Manors\nSouth Charlottefort, CT 15033     Fuchsia
# ...

# %%
# Top 10 customers based on  Yearly Amount Spent
df.sort_values(by="Yearly Amount Spent",ascending=False).head(10)
# Out:
#                                Email  \
# 65                    kyang@diaz.org
# 157                 asilva@yahoo.com
# 50               william82@gmail.com
# 205  jeffrey54@mcdonald-williams.com
# 368               rhonda01@gmail.com
# 24            youngbarbara@yahoo.com
# 305        randyrobinson@hotmail.com
# 464            susanibarra@yahoo.com
# 151                 alicia85@lee.com
# 396            waltonkaren@gmail.com
#
#                                                Address      Avatar  \
# 65    223 Love Trail Suite 831\nPort Jeffrey, IN 46849   OliveDrab
# 157                         USNV Johnson\nFPO AP 19026       Wheat
# 50          11143 Park Squares\nSamanthatown, UT 97073  SandyBrown
# 205   297 Francis Valley\nSouth Lindsey, NY 13669-5367   Gainsboro
# 368          939 Watson Run\nStaceyberg, VT 58376-0454      Orchid
# 24   019 Elliott Tunnel Suite 190\nNicholsbury, WV ...       Wheat
# 305   14548 Hayes Isle Apt. 436\nGarciaville, IN 65366    DarkGray
# ...

# %% [markdown]
# ### Visualization on Avg. Session Length	,Time on App,	Time on Website	Length of Membership,	Yearly Amount Spent

# %%
fig,axes = plt.subplots(2,2,figsize=(20,10))
axes[0,0].plot(df['Avg. Session Length'],df['Yearly Amount Spent'],'mo')
axes[0,0].set_ylabel("Yearly Amount Spent", fontsize = 10)
axes[0,0].set_xlabel("Avg. Session Length", fontsize = 10)

axes[0,1].plot(df['Time on App'],df['Yearly Amount Spent'],'o')
axes[0,1].set_ylabel("Yearly Amount Spent", fontsize = 10)
axes[0,1].set_xlabel("Time on App", fontsize = 10)

axes[1,0].plot(df['Time on Website'],df['Yearly Amount Spent'],'go')
axes[1,0].set_ylabel("Yearly Amount Spent", fontsize = 10)
axes[1,0].set_xlabel("Time on Website", fontsize = 10)

axes[1,1].plot(df['Length of Membership'],df['Yearly Amount Spent'],'ro')
axes[1,1].set_ylabel("Yearly Amount Spent", fontsize = 10)
axes[1,1].set_xlabel("Length of Membership", fontsize = 10)
# Out:
# Text(0.5, 0, 'Length of Membership')

# %% [markdown]
# # Splitting data into test and train

# %%
X_train,X_test,y_train,y_test =train_test_split(df[["Avg. Session Length","Time on App","Time on Website","Length of Membership"]],
                                                df[["Yearly Amount Spent"]],random_state=42,test_size=0.20)

# %% [markdown]
# # Applying Linear Regression

# %%
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print("Intercept:", lr.intercept_.round(2))
print("Coefficient:", lr.coef_.round(2))
# Out:
# Intercept: [-1044.26]
# Coefficient: [[25.6  38.79  0.31 61.9 ]]

# %%
y_pred = lr.predict(X_test)

# %% [markdown]
# # Evaluating the model

# %%
print('RMSE:', np.sqrt(mean_squared_error(y_test, y_pred)))
print('MAE:', mean_absolute_error(y_test, y_pred))
print('R2:', r2_score(y_test, y_pred))
# Out:
# RMSE: 10.481590584636468
# MAE: 8.558441885315231
# R2: 0.9778130629184127
